# %%
import pandas as pd

# %%
df = pd.read_csv("Combined_DS_v10.csv")
df.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
df.isnull()
# Out:
#      SurveyDate  FormalEducation  ConvertedSalary  Hobby  Country  \
# 0         False            False             True  False    False
# 1         False            False            False  False    False
# 2         False            False             True  False    False
# 3         False            False            False  False    False
# 4         False            False            False  False    False
# ..          ...              ...              ...    ...      ...
# 994       False            False             True  False    False
# 995       False            False            False  False    False
# 996       False            False            False  False    False
# 997       False            False             True  False    False
# 998       False            False            False  False    False
#
#      StackOverflowJobsRecommend  VersionControl    Age  Years Experience  \
# 0                          True           False  False             False
# ...

# %%
df["StackOverflowJobsRecommend"].isnull().sum()
# Out:
# 512

# %%
df.isnull().sum()
# Out:
# SurveyDate                      0
# FormalEducation                 0
# ConvertedSalary               334
# Hobby                           0
# Country                         0
# StackOverflowJobsRecommend    512
# VersionControl                  0
# Age                             0
# Years Experience                0
# Gender                        306
# RawSalary                     334
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1486

# %%
df.notnull()
# Out:
#      SurveyDate  FormalEducation  ConvertedSalary  Hobby  Country  \
# 0          True             True            False   True     True
# 1          True             True             True   True     True
# 2          True             True            False   True     True
# 3          True             True             True   True     True
# 4          True             True             True   True     True
# ..          ...              ...              ...    ...      ...
# 994        True             True            False   True     True
# 995        True             True             True   True     True
# 996        True             True             True   True     True
# 997        True             True            False   True     True
# 998        True             True             True   True     True
#
#      StackOverflowJobsRecommend  VersionControl   Age  Years Experience  \
# 0                         False            True  True              True
# ...

# %%
print(df.shape)
# Out:
# (999, 11)

# %%
new_df = df.dropna(how="any")

# %%
print(new_df.shape)
# Out:
# (264, 11)

# %%
new_df1 = df.dropna(subset=['Gender'])

# %%
print(new_df1.shape)
# Out:
# (693, 11)

# %%
df1 = df['VersionControl'].fillna(value='None Given')
df1
# Out:
# 0                    Git
# 1         Git;Subversion
# 2                    Git
# 3      Zip file back-ups
# 4                    Git
#              ...
# 994           Subversion
# 995                  Git
# 996                  Git
# 997       Git;Subversion
# 998                  Git
# Name: VersionControl, Length: 999, dtype: object

# %%
df["New_Gender"] = df['Gender'].fillna(value='None Given')
df
# Out:
#          SurveyDate                                    FormalEducation  \
# 0     2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1     6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2       6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3       5/9/18 1:06  Some college/university study without earning ...
# 4     4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..              ...                                                ...
# 994  10/19/18 13:50  Some college/university study without earning ...
# 995   4/14/18 15:31           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996    3/21/18 6:34           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997    2/5/18 20:01           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 998   2/11/18 21:23           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %%
print(df['ConvertedSalary'].mean())
print(df['ConvertedSalary'].median())
# Out:
# 92565.16992481203
# 55562.0

# %%
df['ConvertedSalary_without_NaN'] = df['ConvertedSalary'].fillna(df['ConvertedSalary'].mean())

# %%
df['ConvertedSalary_without_NaN'] = df['ConvertedSalary_without_NaN'].astype('int64')

# %%
df.head(3)
# Out:
#       SurveyDate                           FormalEducation  ConvertedSalary  \
# 0  2/28/18 20:20  Bachelor's degree (BA. BS. B.Eng.. etc.)              NaN
# 1  6/28/18 13:26  Bachelor's degree (BA. BS. B.Eng.. etc.)          70841.0
# 2    6/6/18 3:37  Bachelor's degree (BA. BS. B.Eng.. etc.)              NaN
#
#   Hobby       Country  StackOverflowJobsRecommend  VersionControl  Age  \
# 0   Yes  South Africa                         NaN             Git   21
# 1   Yes       Sweeden                         7.0  Git;Subversion   38
# 2    No       Sweeden                         8.0             Git   45
#
#    Years Experience Gender  RawSalary  New_Gender  ConvertedSalary_without_NaN
# 0                13   Male        NaN        Male                        92565
# 1                 9   Male  70,841.00        Male                        70841
# 2                11    NaN        NaN  None Given                        92565

# %%
df['ConvertedSalary'] = df['ConvertedSalary'].fillna(round(df['ConvertedSalary'].mean()))

# %%
df['RawSalary']
# Out:
# 0               NaN
# 1         70,841.00
# 2               NaN
# 3         21,426.00
# 4        £41,671.00
#            ...
# 994             NaN
# 995       58,746.00
# 996      $55,000.00
# 997             NaN
# 998    1,000,000.00
# Name: RawSalary, Length: 999, dtype: object

# %%
df["clean_salary"]=df['RawSalary'].str.replace('[$€£,]', '', regex=True)

# %%
df["clean_salary"]
# Out:
# 0             NaN
# 1        70841.00
# 2             NaN
# 3        21426.00
# 4        41671.00
#           ...
# 994           NaN
# 995      58746.00
# 996      55000.00
# 997           NaN
# 998    1000000.00
# Name: clean_salary, Length: 999, dtype: object

# %%
df['clean_salary'] = df['clean_salary'].astype('float')

# %%
df.head(3)
# Out:
#       SurveyDate                           FormalEducation  ConvertedSalary  \
# 0  2/28/18 20:20  Bachelor's degree (BA. BS. B.Eng.. etc.)          92565.0
# 1  6/28/18 13:26  Bachelor's degree (BA. BS. B.Eng.. etc.)          70841.0
# 2    6/6/18 3:37  Bachelor's degree (BA. BS. B.Eng.. etc.)          92565.0
#
#   Hobby       Country  StackOverflowJobsRecommend  VersionControl  Age  \
# 0   Yes  South Africa                         NaN             Git   21
# 1   Yes       Sweeden                         7.0  Git;Subversion   38
# 2    No       Sweeden                         8.0             Git   45
#
#    Years Experience Gender  RawSalary  New_Gender  \
# 0                13   Male        NaN        Male
# 1                 9   Male  70,841.00        Male
# 2                11    NaN        NaN  None Given
#
#    ConvertedSalary_without_NaN  clean_salary
# 0                        92565           NaN
# 1                        70841       70841.0
# ...

# %%
df['clean_salary'].mean() , df['clean_salary'].median()
# Out:
# (92565.16992481203, 55562.0)

# %%
coerced_vals = pd.to_numeric(df['RawSalary'], errors='coerce')
coerced_vals
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 994   NaN
# 995   NaN
# 996   NaN
# 997   NaN
# 998   NaN
# Name: RawSalary, Length: 999, dtype: float64

# %%
df[coerced_vals.isna()].head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0          92565.0   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2          92565.0    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary  New_Gender  \
# ...
